# %% [markdown]
# <a href="https://colab.research.google.com/github/itachi0229/EL3/blob/main/Groupby_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# KAREN MACALINO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mGalarnyk/Tutorial_Data/master/Pandas/CalIt2.data')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mGalarnyk/Tutorial_Data/master/Pandas/CalIt2.data', header = None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10080 entries, 0 to 10079
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10080 non-null  int64
#  1   1       10080 non-null  object
#  2   2       10080 non-null  object
#  3   3       10080 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 315.1+ KB

# %%
df.describe().round(2)
# Out:
#              0         3
# count  10080.0  10080.00
# mean       8.0      3.81
# std        1.0      6.44
# min        7.0      0.00
# 25%        7.0      0.00
# 50%        8.0      0.00
# 75%        9.0      5.00
# max        9.0     62.00

# %%
df.rename(columns = {'old_Flow_ID':'new_FlowID'}, inplace = True)

# %%
df.rename(columns = {'old_1':'new_Date'}, inplace = True)

# %%
df.rename(columns = {'old_2':'new_Time'}, inplace = True)

# %%
df.rename(columns = {'old_3':'new_Count'}, inplace = True)

# %%
df.describe().round(3)
# Out:
#              0          3
# count  10080.0  10080.000
# mean       8.0      3.813
# std        1.0      6.436
# min        7.0      0.000
# 25%        7.0      0.000
# 50%        8.0      0.000
# 75%        9.0      5.000
# max        9.0     62.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10080 entries, 0 to 10079
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10080 non-null  int64
#  1   1       10080 non-null  object
#  2   2       10080 non-null  object
#  3   3       10080 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 315.1+ KB

# %%
df.head()
# Out:
#    0         1         2  3
# 0  7  07/24/05  00:00:00  0
# 1  9  07/24/05  00:00:00  0
# 2  7  07/24/05  00:30:00  1
# 3  9  07/24/05  00:30:00  0
# 4  7  07/24/05  01:00:00  0

# %%
df = pd.DataFrame({'Flow_ID'
                    
                   'Date'
                   'Time'
                    
                   'Count'})
 

display(df)
# Out:
#                       0
# 0  Flow_IDDateTimeCount

# %%
df = pd.DataFrame({'Flow_ID': ["7"],
                    
                   'Date': ["July 24 2005"]})
 

display(df)
# Out:
#   Flow_ID          Date
# 0       7  July 24 2005

# %%
gk = df.groupby('Flow_ID')
gk.first()
# Out:
#                  Date
# Flow_ID
# 7        July 24 2005
